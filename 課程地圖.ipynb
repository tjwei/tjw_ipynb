# %%
from graphviz import Digraph
from math import isnan

# %%
import pandas

# %%
def get_info(url):
    原始資料 = pandas.read_html(url, encoding="utf8")[1]
    學程 = 原始資料[原始資料[2].notnull()]
    學程=學程.set_index(學程[0]).drop(0, 1)
    學程.columns = 學程.iloc[0]
    學程 = 學程[1:]
    學程['學分']=學程['學分'].astype(float)
    return 學程

# %%
# 104 學年度應數基礎學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000003,B,AM___1042971'
基礎 = get_info(url)
基礎
# Out:
# 科目名稱                                                  英文科目名稱       科目代碼  學分  \
# 0
# 微積分(一)                                          Calculus (I)  AM__10000   4
# 微積分(二)                                          Calculus(II)  AM__10200   4
# 線性代數(一)                                   Linear Algebra (I)  AM__10600   3
# 線性代數(二)                                  Linear Algebra (II)  AM__10900   3
# 數學導論                             Introduction to mathematics  AM__11000   3
# 程式設計(一)             Introduction to Computer Programming (I)  CSIE10400   3
# 軟體實作與計算實驗  Software Implementations and Computation Exper...  AM__11300   3
# 計算機概論                       Introduction to Computer Science  CSIE10200   3
#
# 科目名稱      年級 學期 修別 *先修科目或#背景科目   備註
# 0
# 微積分(一)     一  上  必         NaN  NaN
# 微積分(二)     一  下  必     #微積分(一)  NaN
# 線性代數(一)    一  下  必         NaN  NaN
# 線性代數(二)    二  上  必    #線性代數(一)  NaN
# 數學導論       一  上  必         NaN  NaN
# 程式設計(一)    一  下  選         NaN  NaN
# 軟體實作與計算實驗  一  下  選         NaN  NaN
# 計算機概論      一  上  選         NaN  NaN

# %%
# 104 學年度數學科學組核心(一)學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000007,B,AM___1042971'
數科組核心一  = get_info(url)
數科組核心一
# Out:
# 科目名稱                                     英文科目名稱       科目代碼  學分 年級 學期 修別  \
# 0
# 高等微積分(一)                   Advanced Calculus（I）  AM__20600   4  二  上  必
# 高等微積分(二)                 Advanced Calculus (II)  AM__20900   4  二  下  必
# 代數(一)                               Algebra (I)  AM__30900   3  三  上  必
# 數值方法                          Numerical Methods  AM__30000   3  三  下  必
# 微分方程                     Differential Equations  AM__31300   3  三  下  必
# 分析導論      Introduction to Mathematical Analysis  AM__11500   3  一  下  選
# 高等線性代數                  Advanced Linear Algebra  AM__21820   3  二  下  選
# 向量分析                            Vector Analysis  AM__21810   3  二  上  選
# 數論                                Number Theory  AM__31700   3  三  下  選
#
# 科目名稱                    *先修科目或#背景科目   備註
# 0
# 高等微積分(一)            *微積分(一)/*微積分(二)  NaN
# 高等微積分(二)  #高等微積分(一)/*微積分(一)/*微積分(二)  NaN
# 代數(一)                           NaN  NaN
# 數值方法                #線性代數(一)/#計算機概論  NaN
# 微分方程                #微積分(一)/#微積分(二)  NaN
# 分析導論                          #數學導論  NaN
# 高等線性代數            #線性代數(一)/#線性代數(二)  NaN
# 向量分析                #微積分(一)/#微積分(二)  NaN
# 數論                              NaN  NaN

# %%
# 104 學年度數學科學組核心(二)學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000008,B,AM___1042971'
數科組核心二  = get_info(url)
數科組核心二
# Out:
# 科目名稱                              英文科目名稱       科目代碼  學分 年級 學期 修別  \
# 0
# 複變函數論                   Complex Analysis  AM__31800   3  三  上  選
# 實變函數論                      Real Analysis  AM__31900   3  三  下  選
# 幾何                              Geometry  AM__31000   3  三  上  選
# 代數(二)                       Algebra (II)  AM__31200   3  三  下  選
# 其它選修(一)                       others (I)  AM__@0010   3  四  上  選
# 基礎機率         Introduction to Probability  AM__20800   3  二  上  選
# 離散數學                Discrete Mathematics  AM__10400   3  二  下  選
# 統計學                           Statistics  AM__21100   3  二  下  選
# 機率論                   Probability Theory  AM__20400   3  三  上  選
# 拓樸學                             Topology  AM__31500   3  三  上  選
# 數理統計學(一)     Mathematical Statistics (Ⅰ)  AM__31100   3  三  上  選
# 數學規劃            Mathematical Programming  AM__32000   3  三  上  選
# 隨機模型                   Stochastic Models  AM__40200   3  三  下  選
# 傅氏分析                    Fourier Analysis  AM__40100   3  三  下  選
# 對局論                          Game Theory  AM__@0030   3  四  上  選
# 偏微分方程     Partial Differential Equations  AM__40610   3  四  上  選
# 集合論                           Set Theory  AM__40500   3  四  上  選
# 應數專論       Topics in Applied Mathematics  AM__40000   3  四  下  選
# 動態系統                   Dynamical Systems  AM__40620   3  四  下  選
# 其它選修(二)                      others (II)  AM__@0020   3  四  下  選
# 其它選修(三)                     others (III)  AM__@0040   3  四  下  選
#
# 科目名稱                            *先修科目或#背景科目   備註
# 0
# 複變函數論                   #高等微積分(一)/#高等微積分(二)  NaN
# 實變函數論                   #高等微積分(一)/#高等微積分(二)  NaN
# 幾何        #微積分(一)/#微積分(二)/#線性代數(一)/#線性代數(二)  NaN
# 代數(二)                                #代數(一)  NaN
# 其它選修(一)                                 NaN  詳見四
# 基礎機率                        #微積分(一)/#微積分(二)  NaN
# 離散數學                                    NaN  NaN
# 統計學                                   #基礎機率  NaN
# 機率論                                   #基礎機率  NaN
# 拓樸學                                     NaN  NaN
# 數理統計學(一)                         #統計學/#基礎機率  NaN
# 數學規劃                      #線性代數(一)/#線性代數(二)  NaN
# 隨機模型                                  #基礎機率  NaN
# 傅氏分析                                    NaN  NaN
# 對局論                                     NaN  NaN
# 偏微分方程                                   NaN  NaN
# 集合論                                     NaN  NaN
# 應數專論                                    NaN  NaN
# 動態系統                                    NaN  NaN
# 其它選修(二)                                 NaN  詳見四
# 其它選修(三)                                 NaN  詳見四

# %%
# 104 學年度統計資料分析學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000010,B,AM___1042971'
統計資料分析  = get_info(url)
統計資料分析
# Out:
# 科目名稱                                               英文科目名稱       科目代碼  學分 年級  \
# 0
# 數理統計學(一)                      Mathematical Statistics (Ⅰ)  AM__31100   3  三
# 迴歸分析                                  Regression Analysis  AM__40300   3  三
# 程式設計(一)          Introduction to Computer Programming (I)  CSIE10400   3  一
# 高等線性代數                            Advanced Linear Algebra  AM__21820   3  二
# 統計軟體與實務應用  Statistical Software and Practical Application  AM__@0060   3  二
# 精算學                                     Actuarial Science  AM__21600   3  二
# 機率論                                    Probability Theory  AM__20400   3  三
# 數學規劃                             Mathematical Programming  AM__32000   3  三
# 數值方法                                    Numerical Methods  AM__30000   3  三
# 數理統計學(二)                     Mathematical Statistics (II)  AM__31400   3  三
# 時間序列                                          Time Series  AM__32600   3  三
# 隨機模型                                    Stochastic Models  AM__40200   3  三
# 實驗設計                                Design of Experiments  AM__40710   3  三
#
# 科目名稱      學期 修別           *先修科目或#背景科目   備註
# 0
# 數理統計學(一)   上  必            #統計學/#基礎機率  NaN
# 迴歸分析       上  必  #統計學/#基礎機率/#數理統計學(一)  NaN
# 程式設計(一)    下  選                   NaN  NaN
# 高等線性代數     下  選     #線性代數(一)/#線性代數(二)  NaN
# 統計軟體與實務應用  下  選                   NaN  NaN
# 精算學        下  選         #微積分(一)/#基礎機率  NaN
# 機率論        上  選                 #基礎機率  NaN
# 數學規劃       上  選     #線性代數(一)/#線性代數(二)  NaN
# 數值方法       下  選       #線性代數(一)/#計算機概論  NaN
# 數理統計學(二)   下  選             #數理統計學(一)  NaN
# 時間序列       下  選                  #統計學  NaN
# 隨機模型       下  選                 #基礎機率  NaN
# 實驗設計       下  選                  #統計學  NaN

# %%
# 104 學年度數學學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000014,B,AM___1042971'
數學  = get_info(url)
數學
# Out:
# 科目名稱                            英文科目名稱       科目代碼  學分 年級 學期 修別  \
# 0
# 複變函數論                 Complex Analysis  AM__31800   3  三  上  必
# 代數(二)                     Algebra (II)  AM__31200   3  三  下  必
# 微分方程            Differential Equations  AM__31300   3  三  下  必
# 實變函數論                    Real Analysis  AM__31900   3  三  下  必
# 向量分析                   Vector Analysis  AM__21810   3  二  上  選
# 高等線性代數         Advanced Linear Algebra  AM__21820   3  二  下  選
# 離散數學              Discrete Mathematics  AM__10400   3  二  下  選
# 機率論                 Probability Theory  AM__20400   3  三  上  選
# 拓樸學                           Topology  AM__31500   3  三  上  選
# 幾何                            Geometry  AM__31000   3  三  上  選
# 數論                       Number Theory  AM__31700   3  三  下  選
# 傅氏分析                  Fourier Analysis  AM__40100   3  三  下  選
# 對局論                        Game Theory  AM__@0030   3  四  上  選
# 偏微分方程   Partial Differential Equations  AM__40610   3  四  上  選
# 集合論                         Set Theory  AM__40500   3  四  上  選
# 應數專論     Topics in Applied Mathematics  AM__40000   3  四  下  選
# 動態系統                 Dynamical Systems  AM__40620   3  四  下  選
#
# 科目名稱                          *先修科目或#背景科目   備註
# 0
# 複變函數論                 #高等微積分(一)/#高等微積分(二)  NaN
# 代數(二)                              #代數(一)  NaN
# 微分方程                      #微積分(一)/#微積分(二)  NaN
# 實變函數論                 #高等微積分(一)/#高等微積分(二)  NaN
# 向量分析                      #微積分(一)/#微積分(二)  NaN
# 高等線性代數                  #線性代數(一)/#線性代數(二)  NaN
# 離散數學                                  NaN  NaN
# 機率論                                 #基礎機率  NaN
# 拓樸學                                   NaN  NaN
# 幾何      #微積分(一)/#微積分(二)/#線性代數(一)/#線性代數(二)  NaN
# 數論                                    NaN  NaN
# 傅氏分析                                  NaN  NaN
# 對局論                                   NaN  NaN
# 偏微分方程                                 NaN  NaN
# 集合論                                   NaN  NaN
# 應數專論                                  NaN  NaN
# 動態系統                                  NaN  NaN

# %%
# 104 學年度資訊計算學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000013,B,AM___1042971'
資訊計算  = get_info(url)
資訊計算
# Out:
# 科目名稱                                          英文科目名稱       科目代碼  學分 年級 學期 修別  \
# 0
# 基礎機率                     Introduction to Probability  AM__20800   3  二  上  選
# 離散數學                            Discrete Mathematics  AM__10400   3  二  下  選
# 統計學                                       Statistics  AM__21100   3  二  下  選
# 微分方程                          Differential Equations  AM__31300   3  三  下  選
# 資料結構                                 Data Structures  CSIE20000   3  二  上  選
# 程式設計(二)    Introduction to Computer Programming (II)  CSIE10500   3  二  下  選
# 作業系統                               Operating Systems  CSIE30200   3  三  上  選
# 時間序列                                     Time Series  AM__32600   3  三  下  選
# 微陣列基因資料分析                   Microarray Data Analysis  AM__32700   3  四  上  選
# 演算法                                       Algorithms  CSIE20800   3  四  下  選
#
# 科目名稱           *先修科目或#背景科目   備註
# 0
# 基礎機率       #微積分(一)/#微積分(二)  NaN
# 離散數學                   NaN  NaN
# 統計學                  #基礎機率  NaN
# 微分方程       #微積分(一)/#微積分(二)  NaN
# 資料結構                   NaN  NaN
# 程式設計(二)                NaN  NaN
# 作業系統                   NaN  NaN
# 時間序列                  #統計學  NaN
# 微陣列基因資料分析              NaN  NaN
# 演算法                    NaN  NaN

# %%
# 104 學年度數學科學學程
url = 'http://sys.ndhu.edu.tw/aa/class/RuleSearch/RuleDetail.aspx?id=104,1040000119,B,AM___1042971'
數學科學  = get_info(url)
數學科學
# Out:
# 科目名稱                                               英文科目名稱       科目代碼  學分 年級  \
# 0
# 分析導論                Introduction to Mathematical Analysis  AM__11500   3  一
# 程式設計(一)          Introduction to Computer Programming (I)  CSIE10400   3  一
# 基礎機率                          Introduction to Probability  AM__20800   3  二
# 向量分析                                      Vector Analysis  AM__21810   3  二
# 高等線性代數                            Advanced Linear Algebra  AM__21820   3  二
# 資料結構                                      Data Structures  CSIE20000   3  二
# 離散數學                                 Discrete Mathematics  AM__10400   3  二
# 統計學                                            Statistics  AM__21100   3  二
# 精算學                                     Actuarial Science  AM__21600   3  二
# 程式設計(二)         Introduction to Computer Programming (II)  CSIE10500   3  二
# 統計軟體與實務應用  Statistical Software and Practical Application  AM__@0060   3  二
# 機率論                                    Probability Theory  AM__20400   3  三
# 幾何                                               Geometry  AM__31000   3  三
# 數理統計學(一)                      Mathematical Statistics (Ⅰ)  AM__31100   3  三
# 拓樸學                                              Topology  AM__31500   3  三
# 複變函數論                                    Complex Analysis  AM__31800   3  三
# 數學規劃                             Mathematical Programming  AM__32000   3  三
# 迴歸分析                                  Regression Analysis  AM__40300   3  三
# 作業系統                                    Operating Systems  CSIE30200   3  三
# 數值方法                                    Numerical Methods  AM__30000   3  三
# 代數(二)                                        Algebra (II)  AM__31200   3  三
# 微分方程                               Differential Equations  AM__31300   3  三
# 數理統計學(二)                     Mathematical Statistics (II)  AM__31400   3  三
# 數論                                          Number Theory  AM__31700   3  三
# 實變函數論                                       Real Analysis  AM__31900   3  三
# 時間序列                                          Time Series  AM__32600   3  三
# 隨機模型                                    Stochastic Models  AM__40200   3  三
# 傅氏分析                                     Fourier Analysis  AM__40100   3  三
# 實驗設計                                Design of Experiments  AM__40710   3  三
# 微陣列基因資料分析                        Microarray Data Analysis  AM__32700   3  四
# 對局論                                           Game Theory  AM__@0030   3  四
# 偏微分方程                      Partial Differential Equations  AM__40610   3  四
# 集合論                                            Set Theory  AM__40500   3  四
# 應數專論                        Topics in Applied Mathematics  AM__40000   3  四
# 動態系統                                    Dynamical Systems  AM__40620   3  四
# 演算法                                            Algorithms  CSIE20800   3  四
#
# 科目名稱      學期 修別                        *先修科目或#背景科目   備註
# 0
# 分析導論       下  選                              #數學導論  NaN
# 程式設計(一)    下  選                                NaN  NaN
# 基礎機率       上  選                    #微積分(一)/#微積分(二)  NaN
# 向量分析       上  選                    #微積分(一)/#微積分(二)  NaN
# 高等線性代數     下  選                  #線性代數(一)/#線性代數(二)  NaN
# 資料結構       上  選                                NaN  NaN
# 離散數學       下  選                                NaN  NaN
# 統計學        下  選                              #基礎機率  NaN
# 精算學        下  選                      #微積分(一)/#基礎機率  NaN
# 程式設計(二)    下  選                                NaN  NaN
# 統計軟體與實務應用  下  選                                NaN  NaN
# 機率論        上  選                              #基礎機率  NaN
# 幾何         上  選  #微積分(一)/#微積分(二)/#線性代數(一)/#線性代數(二)  NaN
# 數理統計學(一)   上  選                         #統計學/#基礎機率  NaN
# 拓樸學        上  選                                NaN  NaN
# 複變函數論      上  選                #高等微積分(一)/#高等微積分(二)  NaN
# 數學規劃       上  選                  #線性代數(一)/#線性代數(二)  NaN
# 迴歸分析       上  選               #統計學/#基礎機率/#數理統計學(一)  NaN
# 作業系統       上  選                                NaN  NaN
# 數值方法       下  選                    #線性代數(一)/#計算機概論  NaN
# 代數(二)      下  選                             #代數(一)  NaN
# 微分方程       下  選                    #微積分(一)/#微積分(二)  NaN
# 數理統計學(二)   下  選                          #數理統計學(一)  NaN
# 數論         下  選                                NaN  NaN
# 實變函數論      下  選                #高等微積分(一)/#高等微積分(二)  NaN
# 時間序列       下  選                               #統計學  NaN
# 隨機模型       下  選                              #基礎機率  NaN
# 傅氏分析       下  選                                NaN  NaN
# 實驗設計       下  選                               #統計學  NaN
# 微陣列基因資料分析  上  選                                NaN  NaN
# 對局論        上  選                                NaN  NaN
# 偏微分方程      上  選                                NaN  NaN
# 集合論        上  選                                NaN  NaN
# 應數專論       下  選                                NaN  NaN
# 動態系統       下  選                                NaN  NaN
# 演算法        下  選                                NaN  NaN

# %%
數科組學程名稱 = ['基礎', '數學', '數學科學', '數科組核心一', '數科組核心二', '統計資料分析', '資訊計算']
數科組學程 ={x:globals()[x] for x in 數科組學程名稱}

# %%
for k in 基礎.iloc[1].keys():
    print(k+":", 基礎.iloc[1][k])
# Out:
# 英文科目名稱: Calculus(II)
# 科目代碼: AM__10200
# 學分: 4.0
# 年級: 一
# 學期: 下
# 修別: 必
# *先修科目或#背景科目: #微積分(一)
# 備註: nan

# %%
course_data = {}
for k,x in 數科組學程.items():
    for i in x.index:
        if i not in course_data:
            #print(i, x.loc[i])
            course_data[i]=dict(x.loc[i])
            course_data[i]['學程'] = [k]
            if not isinstance(course_data[i]['*先修科目或#背景科目'], str):
                course_data[i]['*先修科目或#背景科目'] = ([], [], set())
            else:
                s = course_data[i]['*先修科目或#背景科目'].split('/')
                先修 = [y[1:] for y in s if y[0]=='*']
                背景 = [y[1:] for y in s if y[0]=='#']
                多餘 = set()
                course_data[i]['*先修科目或#背景科目'] =(先修, 背景, 多餘)
        else:
            course_data[i]['學程'].append(k)
            if x.loc[i]['修別'] == '必':
                course_data[i]['修別'] = '必'

# %%
# 去除多餘
for i in range(10):
    for k,v in course_data.items():
        for g0 in v['*先修科目或#背景科目'][0]+v['*先修科目或#背景科目'][1]:
                for g2 in course_data[g0]['*先修科目或#背景科目']:
                    for g3 in g2:
                        v['*先修科目或#背景科目'][2].add(g3)

# %%
dot = Digraph(comment="課程地圖", graph_attr={"rankdir":"TB"}, node_attr={"fontname":"Noto Sans CJK TC"})

數科組學程顏色 = {'基礎':"#aaaaaa", 
                 '數學': "red", 
                 '數學科學': "#7f5500", 
                 '數科組核心一': "grey", 
                 '數科組核心二': "black", 
                  '統計資料分析': "blue", 
                  '資訊計算': "green"}
數科組學程符號 = {'基礎':"🏗", 
                 '數學': "π", 
                 '數學科學': "🔬", 
                 '數科組核心一': "💙", 
                 '數科組核心二': "💕", 
                  '統計資料分析': "📊", 
                  '資訊計算': "💻"}

年級 = "一二三四"
level = [i+t for i in 年級 for t in "上下"]
for k,v in course_data.items():
    shape = "box"
    style = "filled"
    if v['修別'] == '選':
        style += ", rounded"
    color = {'一': "#ffeeee", "二": "#ffeeff", "三": "#ddddee", "四": "#ccddff"}[v['年級']]
    l = '''<
    # %s <BR /> %s>'''%(k, 
            " ".join("<FONT POINT-SIZE='12' color='%s'>%s</FONT>"%(數科組學程顏色[z],數科組學程符號[z]) for z in sorted(v['學程'])))
    dot.node(k,  l, fillcolor = color, style=style, shape=shape)

for n in level:
    dot.node(n,n, style="invis")
for i in range(len(level)-1):
    dot.edge(level[i], level[i+1], style="invis")
for k,v in course_data.items():
    dot.edge(v['年級']+v['學期'], k , style="invis")
    for g in v['*先修科目或#背景科目'][0]:
        if g not in v['*先修科目或#背景科目'][2]:
            dot.edge(g, k, color="blue")
    for g in v['*先修科目或#背景科目'][1]:
        if g not in v['*先修科目或#背景科目'][2]:
            dot.edge(g, k, color="#007f00")
dot

# %%
dot.render('數科組課程地圖', view=True)
# Out:
# '數科組課程地圖.pdf'
